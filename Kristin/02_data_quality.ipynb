# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load your cleaned data
file_path = '../Kristin/cleaned_properties.csv'
df = pd.read_csv(file_path)

# --- 1. Basic info ---
print("=== DataFrame Info ===")
df.info()

print("\n=== Number of missing values per column ===")
missing_counts = df.isna().sum()
display(missing_counts.sort_values(ascending=False))

print("\n=== Percentage of missing values per column ===")
missing_percent = df.isna().mean() * 100
display(missing_percent.sort_values(ascending=False))

# --- 2. Visualize missing data using seaborn heatmap ---
plt.figure(figsize=(12,6))
sns.heatmap(df.isna(), cbar=False)
plt.title("Missing Values Heatmap")
plt.show()

# --- 3. Identify rows with high missing values ---
df['missing_count'] = df.isna().sum(axis=1)
print("\nRows with highest missing counts:")
display(df.sort_values('missing_count', ascending=False).head(10))
# Out:
# === DataFrame Info ===
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75504 entries, 0 to 75503
# Data columns (total 30 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              75504 non-null  int64
#  1   price                           75504 non-null  int64
#  2   property_type                   75504 non-null  object
#  3   subproperty_type                75504 non-null  object
#  4   region                          75501 non-null  object
#  5   province                        75501 non-null  object
#  6   locality                        75501 non-null  object
#  7   zip_code                        75504 non-null  int64
#  8   latitude                        61407 non-null  float64
#  9   longitude                       61407 non-null  float64
#  10  construction_year               75504 non-null  int64
#  11  total_area_sqm                  75504 non-null  int64
#  12  surface_land_sqm                39254 non-null  float64
#  13  nbr_frontages                   75504 non-null  int64
#  14  nbr_bedrooms                    75504 non-null  int64
#  15  equipped_kitchen                42484 non-null  object
#  16  fl_furnished                    75504 non-null  int64
#  17  fl_open_fire                    75504 non-null  int64
#  18  fl_terrace                      75504 non-null  int64
#  19  terrace_sqm                     75504 non-null  int64
#  20  fl_garden                       75504 non-null  int64
#  21  garden_sqm                      75504 non-null  int64
#  22  fl_swimming_pool                75504 non-null  int64
#  23  fl_floodzone                    75504 non-null  int64
#  24  state_building                  48864 non-null  object
#  25  primary_energy_consumption_sqm  48939 non-null  float64
#  26  epc                             51503 non-null  object
#  27  heating_type                    44063 non-null  object
#  28  fl_double_glazing               75504 non-null  int64
#  29  cadastral_income                30544 non-null  float64
# dtypes: float64(5), int64(16), object(9)
# memory usage: 17.3+ MB
#
# === Number of missing values per column ===
# cadastral_income                  44960
# surface_land_sqm                  36250
# equipped_kitchen                  33020
# heating_type                      31441
# state_building                    26640
# primary_energy_consumption_sqm    26565
# epc                               24001
# longitude                         14097
# latitude                          14097
# locality                              3
# region                                3
# province                              3
# property_type                         0
# subproperty_type                      0
# nbr_frontages                         0
# total_area_sqm                        0
# construction_year                     0
# zip_code                              0
# price                                 0
# id                                    0
# fl_furnished                          0
# nbr_bedrooms                          0
# garden_sqm                            0
# fl_garden                             0
# terrace_sqm                           0
# fl_terrace                            0
# fl_open_fire                          0
# fl_floodzone                          0
# fl_swimming_pool                      0
# fl_double_glazing                     0
# dtype: int64
# === Percentage of missing values per column ===
# cadastral_income                  59.546514
# surface_land_sqm                  48.010701
# equipped_kitchen                  43.732782
# heating_type                      41.641502
# state_building                    35.282899
# primary_energy_consumption_sqm    35.183566
# epc                               31.787720
# longitude                         18.670534
# latitude                          18.670534
# locality                           0.003973
# region                             0.003973
# province                           0.003973
# property_type                      0.000000
# subproperty_type                   0.000000
# nbr_frontages                      0.000000
# total_area_sqm                     0.000000
# construction_year                  0.000000
# zip_code                           0.000000
# price                              0.000000
# id                                 0.000000
# fl_furnished                       0.000000
# nbr_bedrooms                       0.000000
# garden_sqm                         0.000000
# fl_garden                          0.000000
# terrace_sqm                        0.000000
# fl_terrace                         0.000000
# fl_open_fire                       0.000000
# fl_floodzone                       0.000000
# fl_swimming_pool                   0.000000
# fl_double_glazing                  0.000000
# dtype: float64
# Rows with highest missing counts:
#              id     price property_type subproperty_type            region  \
# 63124  47220000   5095000     APARTMENT        PENTHOUSE               NaN
# 52162  16170000   2165000     APARTMENT      FLAT_STUDIO               NaN
# 10383  26276000  16800000         HOUSE      MANOR_HOUSE               NaN
# 8678   59496000   4377140     APARTMENT        APARTMENT          Flanders
# 73057  69090000   4000000     APARTMENT        APARTMENT  Brussels-Capital
# 36440  44319000   3290000     APARTMENT           DUPLEX          Wallonia
# 9209   25881000   3454400     APARTMENT        APARTMENT          Flanders
# 73300  70867000   1730000     APARTMENT      FLAT_STUDIO          Wallonia
# 70     30123000   3566000     APARTMENT        APARTMENT          Flanders
# 23539  13624000   6500000     APARTMENT        APARTMENT          Wallonia
#
#               province   locality  zip_code  latitude  longitude  ...  \
# 63124              NaN        NaN      8535       NaN        NaN  ...
# 52162              NaN        NaN      8539       NaN        NaN  ...
# 10383              NaN        NaN      4525       NaN        NaN  ...
# 8678           Antwerp    Antwerp      2650       NaN        NaN  ...
# 73057         Brussels   Brussels      1000       NaN        NaN  ...
# 36440          Hainaut  Charleroi      6230       NaN        NaN  ...
# 9209           Antwerp    Antwerp      2650       NaN        NaN  ...
# 73300            Liège      Liège      4000       NaN        NaN  ...
# 70             Limburg    Hasselt      3520       NaN        NaN  ...
# 23539  Walloon Brabant   Nivelles      1480       NaN        NaN  ...
#
#        garden_sqm  fl_swimming_pool  fl_floodzone  state_building  \
# 63124           0                 0             1             NaN
# 52162           0                 0             1             NaN
# 10383           0                 0             0            GOOD
# 8678            0                 0             1             NaN
# 73057           0                 0             1             NaN
# 36440           0                 0             0             NaN
# 9209            0                 0             1             NaN
# 73300           0                 0             1             NaN
# 70              0                 0             1             NaN
# 23539           0                 0             0             NaN
#
#        primary_energy_consumption_sqm  epc  heating_type  fl_double_glazing  \
# 63124                             NaN  NaN           NaN                  0
# 52162                             NaN  NaN           NaN                  0
# 10383                             NaN  NaN           NaN                  0
# 8678                              NaN  NaN           NaN                  0
# 73057                             NaN  NaN           NaN                  0
# 36440                             NaN  NaN           NaN                  1
# 9209                              NaN  NaN           NaN                  0
# 73300                             NaN  NaN           NaN                  0
# 70                                NaN  NaN           NaN                  0
# 23539                             NaN  NaN           NaN                  0
#
#        cadastral_income  missing_count
# 63124               NaN             12
# 52162               NaN             12
# 10383               NaN             10
# 8678                NaN              9
# 73057               NaN              9
# 36440               NaN              9
# 9209                NaN              9
# 73300               NaN              9
# 70                  NaN              9
# 23539               NaN              9
#
# [10 rows x 31 columns]
