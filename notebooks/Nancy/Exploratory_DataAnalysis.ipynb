# %%
import pandas as pd

# Path to processed CSV
processed_path = r"C:\Users\vande\becode\immo-eliza-cats-analysis\Nancy\Data_quality.csv"

# Load CSV into a DataFrame
df = pd.read_csv(processed_path)

# Quick look at the data
df.head()
# Out:
#          id     price property_type subproperty_type            region  \
# 0  34221000  225000.0     APARTMENT        APARTMENT          Flanders
# 1   2104000  449000.0         HOUSE            HOUSE          Flanders
# 2  34036000  335000.0     APARTMENT        APARTMENT  Brussels-Capital
# 3  58496000  501000.0         HOUSE            HOUSE          Flanders
# 4  48727000  982700.0     APARTMENT           DUPLEX          Wallonia
#
#           province  locality  zip_code   latitude  longitude  ...  fl_garden  \
# 0          Antwerp   Antwerp      2050  51.217172   4.379982  ...          0
# 1    East Flanders      Gent      9185  51.174944   3.845248  ...          0
# 2         Brussels  Brussels      1070  50.842043   4.334543  ...          0
# 3          Antwerp  Turnhout      2275  51.238312   4.817192  ...          0
# 4  Walloon Brabant  Nivelles      1410        NaN        NaN  ...          1
#
#    garden_sqm  fl_swimming_pool  fl_floodzone  state_building  \
# ...

# %%
# Number of observations (rows) and features (columns)
print("Shape of dataset:", df.shape)

# Info about column types and missing values
df.info()

# Basic stats for numeric columns
df.describe()
# Out:
# Shape of dataset: (75511, 30)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75511 entries, 0 to 75510
# Data columns (total 30 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              75511 non-null  int64
#  1   price                           75511 non-null  float64
#  2   property_type                   75511 non-null  object
#  3   subproperty_type                75511 non-null  object
#  4   region                          75511 non-null  object
#  5   province                        75511 non-null  object
#  6   locality                        75511 non-null  object
#  7   zip_code                        75511 non-null  int64
#  8   latitude                        61413 non-null  float64
#  9   longitude                       61413 non-null  float64
#  10  construction_year               42120 non-null  float64
# ...

# %%
# Quantitative variables
quantitative_vars = df.select_dtypes(include=['int64', 'float64']).columns.tolist()

# Qualitative variables
qualitative_vars = df.select_dtypes(include=['object', 'bool', 'category']).columns.tolist()

print("Number of quantitative variables:", len(quantitative_vars))
print(quantitative_vars)

print("\nNumber of qualitative variables:", len(qualitative_vars))
print(qualitative_vars)
# Out:
# Number of quantitative variables: 21
# ['id', 'price', 'zip_code', 'latitude', 'longitude', 'construction_year', 'total_area_sqm', 'surface_land_sqm', 'nbr_frontages', 'nbr_bedrooms', 'fl_furnished', 'fl_open_fire', 'fl_terrace', 'terrace_sqm', 'fl_garden', 'garden_sqm', 'fl_swimming_pool', 'fl_floodzone', 'primary_energy_consumption_sqm', 'fl_double_glazing', 'cadastral_income']
#
# Number of qualitative variables: 9
# ['property_type', 'subproperty_type', 'region', 'province', 'locality', 'equipped_kitchen', 'state_building', 'epc', 'heating_type']
