# %%
import pandas as pd

file1 = '../../data/raw/immoweb_data.csv'
file2 = '../../data/processed/cleaned_properties.csv'

df1 = pd.read_csv(file1, dtype=str)  # dtype=str to avoid numeric issues
df2 = pd.read_csv(file2, dtype=str)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 6
#       3 file1 = '../../data/raw/immoweb_data.csv'
#       4 file2 = '../../data/processed/cleaned_properties.csv'
# ----> 6 df1 = pd.read_csv(file1, dtype=str)  # dtype=str to avoid numeric issues
#       7 df2 = pd.read_csv(file2, dtype=str)
#
# File ~/Desktop/BeCode_Projects/immo-eliza-cats-analysis/.venv/lib/python3.14/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/Desktop/BeCode_Projects/immo-eliza-cats-analysis/.venv/lib/python3.14/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~/Desktop/BeCode_Projects/immo-eliza-cats-analysis/.venv/lib/python3.14/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~/Desktop/BeCode_Projects/immo-eliza-cats-analysis/.venv/lib/python3.14/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~/Desktop/BeCode_Projects/immo-eliza-cats-analysis/.venv/lib/python3.14/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../../data/raw/immoweb_data.csv'

# %%
print("Shape of file1:", df1.shape)
print("Shape of file2:", df2.shape)
# Out:
# Shape of file1: (75511, 30)
# Shape of file2: (75508, 30)

# %%
if df1.equals(df2):
    print("Files are exactly the same.")
else:
    print("Files differ.")
# Out:
# Files differ.

# %%
# Merge to find differences
merged = df1.merge(df2, how='outer', indicator=True)
diff_rows = merged[merged['_merge'] != 'both']
print(f"Number of differing rows: {len(diff_rows)}")
diff_rows.head(10)
# Out:
# Number of differing rows: 103021
#           id     price property_type subproperty_type    region  \
# 0          0  300000.0     APARTMENT        APARTMENT  Wallonia
# 1          0  300000.0     APARTMENT        APARTMENT  Wallonia
# 2     100000  325000.0         HOUSE            HOUSE  Flanders
# 3     100000  325000.0         HOUSE            HOUSE  Flanders
# 4    1000000  310000.0         HOUSE            HOUSE  Wallonia
# 5    1000000  310000.0         HOUSE            HOUSE  Wallonia
# 6   10000000  285000.0         HOUSE            HOUSE  Flanders
# 7   10000000  285000.0         HOUSE            HOUSE  Flanders
# 9   10003000  269000.0         HOUSE            HOUSE  Flanders
# 10  10003000  269000.0         HOUSE            HOUSE  Flanders
#
#            province           locality zip_code    latitude  longitude  ...  \
# 0   Walloon Brabant           Nivelles     1348   50.670463  4.6075182  ...
# 1   Walloon Brabant           Nivelles     1348   50.670463  4.6075182  ...
# 2     East Flanders       Sint-Niklaas     9120  51.2158653  4.2519533  ...
# 3     East Flanders       Sint-Niklaas     9120  51.2158653  4.2519533  ...
# 4        Luxembourg  Marche-en-Famenne     6940  50.3462905  5.3931678  ...
# 5        Luxembourg  Marche-en-Famenne     6940  50.3462905  5.3931678  ...
# 6           Limburg            Hasselt     3800  50.8192907  5.1770649  ...
# 7           Limburg            Hasselt     3800  50.8192907  5.1770649  ...
# 9     West Flanders           Kortrijk     8520  50.8525982  3.2789281  ...
# 10    West Flanders           Kortrijk     8520  50.8525982  3.2789281  ...
#
#    garden_sqm fl_swimming_pool fl_floodzone state_building  \
# 0         0.0                0            1        MISSING
# 1         0.0                0            1        MISSING
# 2         0.0                0            0        MISSING
# 3         0.0                0            0        MISSING
# 4      2472.0                0            1           GOOD
# 5      2472.0                0            1           GOOD
# 6         NaN                0            0  TO_BE_DONE_UP
# 7         NaN                0            0  TO_BE_DONE_UP
# 9        77.0                0            0           GOOD
# 10       77.0                0            0           GOOD
#
#    primary_energy_consumption_sqm   epc heating_type fl_double_glazing  \
# 0                            58.0     A      MISSING                 0
# 1                            58.0  good      MISSING                 0
# 2                           385.0     D          GAS                 1
# 3                           385.0  poor          GAS                 1
# 4                           325.0     D          GAS                 1
# 5                           325.0  poor          GAS                 1
# 6                           277.0     C          GAS                 1
# 7                           277.0  poor          GAS                 1
# 9                           507.0     F      MISSING                 1
# 10                          507.0   bad      MISSING                 1
#
#    cadastral_income      _merge
# 0               NaN   left_only
# 1               NaN  right_only
# 2            2545.0   left_only
# 3            2545.0  right_only
# 4             505.0   left_only
# 5             505.0  right_only
# 6               NaN   left_only
# 7               NaN  right_only
# 9             594.0   left_only
# 10            594.0  right_only
#
# [10 rows x 31 columns]
